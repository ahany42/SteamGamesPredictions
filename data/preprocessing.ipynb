# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv("../datasets/raw/combined_games.csv")
print("Combined shape:",df.shape)
df.info()
# Out:
# Combined shape: (69428, 20)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69428 entries, 0 to 69427
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           7535 non-null   float64
#  1   Full_game_appid      69428 non-null  int64
#  2   demo_appid           7535 non-null   float64
#  3   name_x               7534 non-null   object
#  4   dlc_appid            520 non-null    float64
#  5   name_y               520 non-null    object
#  6   price                69428 non-null  float64
#  7   copiesSold           69428 non-null  int64
#  8   publisherClass       69428 non-null  object
#  9   aiContent            0 non-null      float64
#  10  name                 69428 non-null  object
#  11  metacritic           2933 non-null   float64
#  12  steam_achievements   69428 non-null  bool
#  13  steam_trading_cards  69428 non-null  bool
#  14  workshop_support     69428 non-null  bool
#  15  genres               69324 non-null  object
#  16  achievements_total   37295 non-null  float64
#  17  release_date         69426 non-null  object
#  18  supported_platforms  69428 non-null  object
#  19  reviewScore          69428 non-null  int64
# dtypes: bool(3), float64(7), int64(3), object(7)
# memory usage: 9.2+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0  Full_game_appid    demo_appid     dlc_appid  \
# count   7535.000000     6.942800e+04  7.535000e+03  5.200000e+02
# mean    8137.363504     1.742130e+06  2.070466e+06  1.980804e+06
# std     4220.272502     9.273455e+05  9.626569e+05  1.033833e+06
# min        2.000000     1.000000e+01  2.190000e+02  2.680300e+04
# 25%     4731.500000     9.626250e+05  1.356070e+06  1.038998e+06
# 50%     8431.000000     1.612815e+06  2.099800e+06  2.058890e+06
# 75%    11510.500000     2.581562e+06  2.940835e+06  2.907145e+06
# max    15454.000000     3.515040e+06  3.515720e+06  3.514640e+06
#
#               price    copiesSold  aiContent   metacritic  achievements_total  \
# count  69428.000000  6.942800e+04        0.0  2933.000000        37295.000000
# mean       7.940826  8.584933e+04        NaN    73.669622           39.520043
# std       15.533680  1.820168e+06        NaN    10.233509          239.180351
# min        0.000000  0.000000e+00        NaN    20.000000            0.000000
# 25%        0.990000  6.000000e+01        NaN    68.000000           10.000000
# 50%        4.990000  4.570000e+02        NaN    75.000000           18.000000
# 75%        9.990000  3.955000e+03        NaN    81.000000           32.000000
# max     1900.000000  3.021580e+08        NaN    97.000000         5394.000000
#
#         reviewScore
# count  69428.000000
# mean      71.903843
# std       28.682102
# min        0.000000
# 25%       60.000000
# 50%       80.000000
# 75%       94.000000
# max      100.000000

# %%
df.head()
# Out:
#    Unnamed: 0  Full_game_appid  demo_appid name_x  dlc_appid name_y  price  \
# 0         NaN              730         NaN    NaN        NaN    NaN    0.0
# 1         NaN              570         NaN    NaN        NaN    NaN    0.0
# 2         NaN           578080         NaN    NaN        NaN    NaN    0.0
# 3         NaN              440         NaN    NaN        NaN    NaN    0.0
# 4         NaN          1172470         NaN    NaN        NaN    NaN    0.0
#
#    copiesSold publisherClass  aiContent                 name  metacritic  \
# 0   302158048            AAA        NaN     Counter-Strike 2         NaN
# 1   212896574            AAA        NaN               Dota 2        90.0
# 2   161971233            AAA        NaN  PUBG: BATTLEGROUNDS         NaN
# 3    99060457            AAA        NaN      Team Fortress 2        92.0
# 4    67554185            AAA        NaN        Apex Legends™        88.0
#
#    steam_achievements  steam_trading_cards  workshop_support  \
# 0               False                 True              True
# 1               False                 True              True
# 2               False                False             False
# 3                True                 True              True
# 4                True                 True             False
#
#                                               genres  achievements_total  \
# 0                               Action, Free To Play                 1.0
# 1                     Action, Strategy, Free To Play                 NaN
# 2  Action, Adventure, Massively Multiplayer, Free...                37.0
# 3                               Action, Free To Play               520.0
# 4                    Action, Adventure, Free To Play                12.0
#
#    release_date          supported_platforms  reviewScore
# 0  Aug 21, 2012         ['windows', 'linux']           87
# 1   Jul 9, 2013  ['windows', 'mac', 'linux']           82
# 2  Dec 21, 2017                  ['windows']           59
# 3  Oct 10, 2007         ['windows', 'linux']           90
# 4   Nov 4, 2020                  ['windows']           67

# %%
df.tail()
# Out:
#        Unnamed: 0  Full_game_appid  demo_appid name_x  dlc_appid name_y  \
# 69423         NaN           738230         NaN    NaN        NaN    NaN
# 69424         NaN           713550         NaN    NaN        NaN    NaN
# 69425         NaN           700050         NaN    NaN        NaN    NaN
# 69426         NaN           679960         NaN    NaN        NaN    NaN
# 69427         NaN          3167760         NaN    NaN        NaN    NaN
#
#        price  copiesSold publisherClass  aiContent                  name  \
# 69423   4.99           0       Hobbyist        NaN             High Noon
# 69424   4.99           0       Hobbyist        NaN         Hikaru's Cube
# 69425   0.99           0       Hobbyist        NaN            Bees Knees
# 69426   0.99           0       Hobbyist        NaN           Brain Crush
# 69427   4.99           0       Hobbyist        NaN  DUNGEON WALK3－奇妙な狂闘－
#
#        metacritic  steam_achievements  steam_trading_cards  workshop_support  \
# 69423         NaN               False                False             False
# 69424         NaN               False                False             False
# 69425         NaN                True                False             False
# 69426         NaN               False                False             False
# 69427         NaN                True                False             False
#
#                                     genres  achievements_total  release_date  \
# 69423     Action, Simulation, Early Access                 NaN   Nov 6, 2017
# 69424  Action, Casual, Indie, Early Access                 NaN  Sep 15, 2017
# 69425                Action, Casual, Indie                11.0   Sep 4, 2017
# 69426                                Indie                 NaN  Aug 18, 2017
# 69427                                Indie                 2.0  Jan 26, 2025
#
#       supported_platforms  reviewScore
# 69423         ['windows']            0
# 69424         ['windows']            0
# 69425         ['windows']            0
# 69426         ['windows']            0
# 69427         ['windows']            0

# %%
df.isna().sum()
# Out:
# Unnamed: 0             61893
# Full_game_appid            0
# demo_appid             61893
# name_x                 61894
# dlc_appid              68908
# name_y                 68908
# price                      0
# copiesSold                 0
# publisherClass             0
# aiContent              69428
# name                       0
# metacritic             66495
# steam_achievements         0
# steam_trading_cards        0
# workshop_support           0
# genres                   104
# achievements_total     32133
# release_date               2
# supported_platforms        0
# reviewScore                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers (df < lower_bound) | (df > upper_bound)
print("Outliers in the dataset:")
print(df[(df < lower_bound) | (df > upper_bound)].sum())
